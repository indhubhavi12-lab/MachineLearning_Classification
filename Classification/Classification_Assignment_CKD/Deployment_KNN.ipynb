# %%
import pandas as pd
import pickle

# Load the model
with open('knn_model.sav', 'rb') as file:
    loaded_model = pickle.load(file)

# Provide new input as a DataFrame with same columns as training
columns = [
    'age','bp','sg','al','su','rbc','pc','pcc','ba','bgr','bu','sc',
    'sod','pot','hrmo','pcv','wc','rc','htn','dm','cad','appet','pe','ane'
]
new_data = pd.DataFrame([[
    45, 76, 1, 0, 148, 57, 3, 0, 1, 0, 137, 4.6, 12, 32, 0, 1, 0, 0, 1, 1, 0, 0, 0, 1
]], columns=columns)

# Predict
prediction = loaded_model.predict(new_data)
print("Predicted class:", prediction[0])
# Out:
# Predicted class: 1
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
